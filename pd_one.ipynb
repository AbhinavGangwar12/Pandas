# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
# print(f"read")

# %%
type(df)
df
# Out:
#                                         Country Name Country Code  \
# 0                                             Poland          POL
# 1                                             Poland          POL
# 2                                             Poland          POL
# 3                                             Poland          POL
# 4                                            Germany          DEU
# 5                                            Germany          DEU
# 6                                            Germany          DEU
# 7                                            Germany          DEU
# 8                                            Belarus          BLR
# 9                                            Belarus          BLR
# 10                                           Belarus          BLR
# 11                                           Belarus          BLR
# 12                                    Czech Republic          CZE
# ...

# %%
df["Country Name"]#recommended
# Out:
# 0                                               Poland
# 1                                               Poland
# 2                                               Poland
# 3                                               Poland
# 4                                              Germany
# 5                                              Germany
# 6                                              Germany
# 7                                              Germany
# 8                                              Belarus
# 9                                              Belarus
# 10                                             Belarus
# 11                                             Belarus
# 12                                      Czech Republic
# 13                                      Czech Republic
# 14                                      Czech Republic
# 15                                      Czech Republic
# 16                                     Slovak Republic
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   42 non-null     object
#  1   Country Code   40 non-null     object
#  2   Series Name    40 non-null     object
#  3   Series Code    40 non-null     object
#  4   1990 [YR1990]  40 non-null     object
#  5   1991 [YR1991]  40 non-null     object
#  6   1992 [YR1992]  40 non-null     object
#  7   1993 [YR1993]  40 non-null     object
#  8   1994 [YR1994]  40 non-null     object
#  9   1995 [YR1995]  40 non-null     object
#  10  1996 [YR1996]  40 non-null     float64
#  11  1997 [YR1997]  40 non-null     float64
#  12  1998 [YR1998]  40 non-null     float64
#  13  1999 [YR1999]  40 non-null     float64
#  14  2000 [YR2000]  40 non-null     float64
#  15  2001 [YR2001]  40 non-null     float64
#  16  2002 [YR2002]  40 non-null     float64
# ...

# %%
df.describe()
# Out:
#        1996 [YR1996]  1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  \
# count   4.000000e+01   4.000000e+01   4.000000e+01   4.000000e+01
# mean    1.446677e+11   1.372287e+11   1.417991e+11   1.406870e+11
# std     5.007280e+11   4.649105e+11   4.780457e+11   4.746504e+11
# min    -1.000000e+01  -3.000000e+00  -1.900000e+00  -8.564951e-01
# 25%     2.766953e+00   3.343499e+00   3.793354e+00   2.573933e+00
# 50%     4.397992e+02   5.021558e+02   4.220885e+02   3.201528e+02
# 75%     1.186549e+09   1.266581e+09   1.404298e+09   1.431744e+09
# max     2.503665e+12   2.218689e+12   2.243226e+12   2.199957e+12
#
#        2000 [YR2000]  2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  \
# count   4.000000e+01   4.000000e+01   4.000000e+01   4.000000e+01
# mean    1.308131e+11   1.316919e+11   1.426754e+11   1.705805e+11
# std     4.369309e+11   4.363973e+11   4.705924e+11   5.633055e+11
# min     1.210176e+00   1.205302e+00  -1.679871e-01  -7.648612e-01
# ...

# %%
df.describe(include="all")
# Out:
#        Country Name Country Code                   Series Name  \
# count            42           40                            40
# unique           12           10                             4
# top          Poland          POL  GDP per capita (current US$)
# freq              4            4                            10
# mean            NaN          NaN                           NaN
# std             NaN          NaN                           NaN
# min             NaN          NaN                           NaN
# 25%             NaN          NaN                           NaN
# 50%             NaN          NaN                           NaN
# 75%             NaN          NaN                           NaN
# max             NaN          NaN                           NaN
#
#            Series Code 1990 [YR1990] 1991 [YR1991] 1992 [YR1992]  \
# count               40            40            40            40
# unique               4            25            33            35
# ...

# %%
df.tail()
df.tail(10)#to see last 10 rows
# Out:
#                                         Country Name Country Code  \
# 35                                           Ukraine          UKR
# 36                                    United Kingdom          GBR
# 37                                    United Kingdom          GBR
# 38                                    United Kingdom          GBR
# 39                                    United Kingdom          GBR
# 40                                               NaN          NaN
# 41                                               NaN          NaN
# 42                                               NaN          NaN
# 43  Data from database: World Development Indicators          NaN
# 44                          Last Updated: 11/17/2016          NaN
#
#                          Series Name        Series Code      1990 [YR1990]  \
# 35                 GDP (current US$)     NY.GDP.MKTP.CD   81456918678.5008
# 36      GDP per capita (current US$)     NY.GDP.PCAP.CD   19095.4669984608
# ...

# %%
df.head()
df.head(10)
# Out:
#   Country Name Country Code                       Series Name  \
# 0       Poland          POL      GDP per capita (current US$)
# 1       Poland          POL  GDP per capita growth (annual %)
# 2       Poland          POL             GDP growth (annual %)
# 3       Poland          POL                 GDP (current US$)
# 4      Germany          DEU      GDP per capita (current US$)
# 5      Germany          DEU  GDP per capita growth (annual %)
# 6      Germany          DEU             GDP growth (annual %)
# 7      Germany          DEU                 GDP (current US$)
# 8      Belarus          BLR      GDP per capita (current US$)
# 9      Belarus          BLR  GDP per capita growth (annual %)
#
#          Series Code     1990 [YR1990]      1991 [YR1991]      1992 [YR1992]  \
# 0     NY.GDP.PCAP.CD  1698.00692240161   2192.66597959689   2411.85949606936
# 1  NY.GDP.PCAP.KD.ZG                ..  -7.34479101398449    2.2010658661186
# ...

# %% [markdown]
# CREATING OUR OWN DATAFRAME
#
# ROW ORIENTED APPROACH

# %%
df.head(2)
# Out:
#   Country Name Country Code                       Series Name  \
# 0       Poland          POL      GDP per capita (current US$)
# 1       Poland          POL  GDP per capita growth (annual %)
#
#          Series Code     1990 [YR1990]      1991 [YR1991]     1992 [YR1992]  \
# 0     NY.GDP.PCAP.CD  1698.00692240161   2192.66597959689  2411.85949606936
# 1  NY.GDP.PCAP.KD.ZG                ..  -7.34479101398449   2.2010658661186
#
#       1993 [YR1993]     1994 [YR1994]     1995 [YR1995]  ...  2007 [YR2007]  \
# 0  2449.30190803207  2819.68946640512  3612.15951448199  ...   11247.551481
# 1  3.47468277389751  5.07085551499688   6.8067989238197  ...       7.259915
#
#    2008 [YR2008]  2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0   13906.218200   11440.578132   12597.458792   13891.141688   13142.045995
# 1       3.906208       2.564657       3.995464       4.952064       1.561950
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]
# ...

# %%
my_df = pd.DataFrame([["Abhinav","Gangwar",20,"Bareilly","Uttar Pradesh","India"]],
                     columns=["FirstName","LastName","Age","City","State","Country"]
                     )
my_df
# Out:
#   FirstName LastName  Age      City          State Country
# 0   Abhinav  Gangwar   20  Bareilly  Uttar Pradesh   India

# %% [markdown]
# COLUMN ORIENTED APPROACH

# %%
data = pd.DataFrame({
    "FirstName" : ["Thomas","Arthur","Elfy"],
    "LastName" : ["Shelby","Shelby","Armor"],
    "Age":[40,49,41],
    "City":["Manhattan","Manhattan","Burminghum"],
    "State":["UK","UK","UK"],
    "Country":["England","England","England"]
})
data
# Out:
#   FirstName LastName  Age        City State  Country
# 0    Thomas   Shelby   40   Manhattan    UK  England
# 1    Arthur   Shelby   49   Manhattan    UK  England
# 2      Elfy    Armor   41  Burminghum    UK  England

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]'],
#       dtype='object')

# %%
df["Country Name"].unique()
# Out:
# array(['Poland', 'Germany', 'Belarus', 'Czech Republic',
#        'Slovak Republic', 'Hungary', 'Estonia', 'France', 'Ukraine',
#        'United Kingdom', nan,
#        'Data from database: World Development Indicators',
#        'Last Updated: 11/17/2016'], dtype=object)

# %%
df["Country Name"].nunique()#gives number of unique values in the column
# Out:
# 12

# %%
# Accessing multiple columns at a time
df[["Country Name","Country Code"]].nunique()
t = df[["Country Name","Country Code"]]
type(t)
df[["Country Name","Country Code"]].value_counts()#not advised
df["Country Code"].value_counts()
type(df["Country Code"].value_counts())
# Out:
# pandas.core.series.Series
