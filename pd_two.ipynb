# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL         65.0     8450   Pave   NaN      Reg
# 1           1       SC20       RL         80.0     9600   Pave   NaN      Reg
# 2           2       SC60       RL         68.0    11250   Pave   NaN      IR1
# 3           3       SC70       RL         60.0     9550   Pave   NaN      IR1
# 4           4       SC60       RL         84.0    14260   Pave   NaN      IR1
# 5           5       SC50       RL         85.0    14115   Pave   NaN      IR1
# 6           6       SC20       RL         75.0    10084   Pave   NaN      Reg
# 7           7       SC60       RL          0.0    10382   Pave   NaN      IR1
# 8           8       SC50       RM         51.0     6120   Pave   NaN      Reg
# 9           9      SC190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# RENAMING COLUMNS

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0       1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       111
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %%
df.rename({"MSSubClass" : "MS_Sub_class"},axis=1)#this will not make changes in original dataframe
df.rename({"MSSubClass" : "MS_Sub_class"},axis=1,inplace="True")#this will make changes in original dataframe
df
# Out:
#       Unnamed: 0 MS_Sub_class MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0         SC60       RL         65.0     8450   Pave   NaN
# 1              1         SC20       RL         80.0     9600   Pave   NaN
# 2              2         SC60       RL         68.0    11250   Pave   NaN
# 3              3         SC70       RL         60.0     9550   Pave   NaN
# 4              4         SC60       RL         84.0    14260   Pave   NaN
# ...          ...          ...      ...          ...      ...    ...   ...
# 1455        1455         SC60       RL         62.0     7917   Pave   NaN
# 1456        1456         SC20       RL         85.0    13175   Pave   NaN
# 1457        1457         SC70       RL         66.0     9042   Pave   NaN
# 1458        1458         SC20       RL         68.0     9717   Pave   NaN
# 1459        1459         SC20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df["Sales-1000"] = df["SalePrice"]-1000#it will take all the corresponding values of the SalesPrice and will perform operation as provided
 
df
# Out:
#       Unnamed: 0 MS_Sub_class MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0         SC60       RL         65.0     8450   Pave   NaN
# 1              1         SC20       RL         80.0     9600   Pave   NaN
# 2              2         SC60       RL         68.0    11250   Pave   NaN
# 3              3         SC70       RL         60.0     9550   Pave   NaN
# 4              4         SC60       RL         84.0    14260   Pave   NaN
# ...          ...          ...      ...          ...      ...    ...   ...
# 1455        1455         SC60       RL         62.0     7917   Pave   NaN
# 1456        1456         SC20       RL         85.0    13175   Pave   NaN
# 1457        1457         SC70       RL         66.0     9042   Pave   NaN
# 1458        1458         SC20       RL         68.0     9717   Pave   NaN
# 1459        1459         SC20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# ROW-VISE OPERATIONS

# %%
#indexing 
import numpy as np
df.index = np.arange(1,df.shape[0]+1,dtype='int')
df
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1              0       SC60       RL         65.0     8450   Pave   NaN
# 2              1       SC20       RL         80.0     9600   Pave   NaN
# 3              2       SC60       RL         68.0    11250   Pave   NaN
# 4              3       SC70       RL         60.0     9550   Pave   NaN
# 5              4       SC60       RL         84.0    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1456        1455       SC60       RL         62.0     7917   Pave   NaN
# 1457        1456       SC20       RL         85.0    13175   Pave   NaN
# 1458        1457       SC70       RL         66.0     9042   Pave   NaN
# 1459        1458       SC20       RL         68.0     9717   Pave   NaN
# 1460        1459       SC20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df.loc[1:4]
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1           0       SC60       RL         65.0     8450   Pave   NaN      Reg
# 2           1       SC20       RL         80.0     9600   Pave   NaN      Reg
# 3           2       SC60       RL         68.0    11250   Pave   NaN      IR1
# 4           3       SC70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 1         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 2         Lvl    AllPub  ...        0     No    No          No       0    May
# 3         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 4         Lvl    AllPub  ...        0     No    No          No       0    Feb
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 1   2008        WD         Normal     208500
# 2   2007        WD         Normal     181500
# 3   2008        WD         Normal     223500
# ...

# %%
temp = df.set_index("LotFrontage")
temp
# Out:
#              Unnamed: 0 MSSubClass MSZoning  LotArea Street Alley LotShape  \
# LotFrontage
# 65.0                  0       SC60       RL     8450   Pave   NaN      Reg
# 80.0                  1       SC20       RL     9600   Pave   NaN      Reg
# 68.0                  2       SC60       RL    11250   Pave   NaN      IR1
# 60.0                  3       SC70       RL     9550   Pave   NaN      IR1
# 84.0                  4       SC60       RL    14260   Pave   NaN      IR1
# ...                 ...        ...      ...      ...    ...   ...      ...
# 62.0               1455       SC60       RL     7917   Pave   NaN      Reg
# 85.0               1456       SC20       RL    13175   Pave   NaN      Reg
# 66.0               1457       SC70       RL     9042   Pave   NaN      Reg
# 68.0               1458       SC20       RL     9717   Pave   NaN      Reg
# 75.0               1459       SC20       RL     9937   Pave   NaN      Reg
#
# ...

# %%
temp.loc[68.0]#scince the indices are in float so i have provided float and these are explicit indices
# Out:
#              Unnamed: 0 MSSubClass MSZoning  LotArea Street Alley LotShape  \
# LotFrontage
# 68.0                  2       SC60       RL    11250   Pave   NaN      IR1
# 68.0                 38       SC20       RL     7922   Pave   NaN      Reg
# 68.0                 53       SC20       RL    50271   Pave   NaN      IR1
# 68.0                192       SC20       RL     9017   Pave   NaN      IR1
# 68.0                257       SC20       RL     8814   Pave   NaN      Reg
# 68.0                350      SC120       RL     7820   Pave   NaN      IR1
# 68.0                395       SC20       RL     9571   Pave   NaN      Reg
# 68.0                410       SC20       RL     9571   Pave   NaN      Reg
# 68.0                756       SC60       RL    10769   Pave   NaN      IR1
# 68.0                978       SC20       RL     9450   Pave   NaN      Reg
# 68.0                985      SC190       RL    10880   Pave   NaN      Reg
# ...

# %%
temp.reset_index(inplace=True)
new = temp.head()

# %%
new
# Out:
#    level_0  index  LotFrontage  Unnamed: 0 MSSubClass MSZoning  LotArea  \
# 0        0      0         65.0           0       SC60       RL     8450
# 1        1      1         80.0           1       SC20       RL     9600
# 2        2      2         68.0           2       SC60       RL    11250
# 3        3      3         60.0           3       SC70       RL     9550
# 4        4      4         84.0           4       SC60       RL    14260
#
#   Street Alley LotShape  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0   Pave   NaN      Reg  ...        0     No    No          No       0    Feb
# 1   Pave   NaN      Reg  ...        0     No    No          No       0    May
# 2   Pave   NaN      IR1  ...        0     No    No          No       0    Sep
# 3   Pave   NaN      IR1  ...        0     No    No          No       0    Feb
# 4   Pave   NaN      IR1  ...        0     No    No          No       0    Dec
#
#   YrSold SaleType SaleCondition  SalePrice
# ...

# %%
new.columns
